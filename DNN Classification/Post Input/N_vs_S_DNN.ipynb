# %%
import numpy as np
import cv2
import csv
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
import random
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load preprocessed data for DNN
file_path = '/content/drive/MyDrive/NLP_Workspace/Data/DNN_Binary_Labeled/'

df_data = pd.read_csv(file_path + "N_vs_S_data.csv")

# %%
df_data.head(10)
df_data.isnull().any()
df_data = df_data.dropna(how='any',axis=0)

# %%
df_data.describe()
# Out:
#                label              0              1              2  \
# count  198642.000000  198642.000000  198642.000000  198642.000000
# mean        0.500035       0.560314       0.361566       0.092869
# std         0.500001       0.645151       0.549036       0.525966
# min         0.000000      -6.305176      -2.542236      -5.718872
# 25%         0.000000       0.096420       0.000000      -0.205322
# 50%         1.000000       0.490601       0.292419       0.075287
# 75%         1.000000       0.974289       0.692070       0.386292
# max         1.000000       4.739014       4.809937       8.631409
#
#                    3              4              5              6  \
# count  198642.000000  198642.000000  198642.000000  198642.000000
# mean        1.250546      -0.868388       0.231778       0.807898
# std         0.831370       0.707000       0.596241       0.726631
# min        -3.269958      -4.513428      -4.694336      -6.679688
# 25%         0.592529      -1.355530      -0.117058       0.245632
# 50%         1.204382      -0.813049       0.188110       0.737976
# 75%         1.817261      -0.311646       0.582733       1.307358
# max         8.592773       2.346924       5.228271       4.490234
#
#                    7              8  ...            290            291  \
# count  198642.000000  198642.000000  ...  198642.000000  198642.000000
# mean       -0.785229       0.887393  ...      -0.640821       0.682973
# std         0.662248       0.691522  ...       0.698269       0.654709
# min        -5.651855      -4.519287  ...      -5.538086      -4.955078
# 25%        -1.199562       0.337402  ...      -1.092712       0.203674
# 50%        -0.708298       0.840485  ...      -0.553322       0.614014
# 75%        -0.284668       1.363037  ...      -0.118652       1.105188
# max         2.821167       5.316772  ...       3.493164       6.076660
#
#                  292            293            294            295  \
# count  198642.000000  198642.000000  198642.000000  198642.000000
# mean       -0.934219       0.030949      -0.645088      -0.402813
# std         0.710346       0.563568       0.668436       0.620389
# min        -5.978973      -5.292908      -5.431641      -7.779053
# 25%        -1.410889      -0.284790      -1.083984      -0.762695
# 50%        -0.864639       0.029785      -0.580490      -0.341309
# 75%        -0.380573       0.351074      -0.161388      -0.002051
# max         2.633789       5.368652       4.992218       3.496752
#
#                  296            297            298            299
# count  198642.000000  198642.000000  198642.000000  198642.000000
# mean        0.355011      -0.582733       0.227410       0.010737
# std         0.656576       0.598409       0.572102       0.553574
# min        -4.625732      -6.010742      -4.319458      -3.177124
# 25%        -0.056183      -0.949890      -0.127441      -0.314087
# 50%         0.288025      -0.516479       0.175903       0.000000
# 75%         0.756836      -0.160156       0.568726       0.318382
# max         5.003540       7.576965      10.454346       5.238281
#
# [8 rows x 301 columns]

# %%
fetched_data = df_data.to_numpy()
len(fetched_data), len(fetched_data[0])
# Out:
# (198642, 301)

# %%
LENGTH_DATA = len(fetched_data)

import random
train_example_nums = int(0.85 * LENGTH_DATA)
test_example_nums = int(0.15 * LENGTH_DATA)

random_ids = [i for i in range(LENGTH_DATA)]
random.Random(4).shuffle(random_ids)

random_train_ids = random_ids[:train_example_nums]
random_test_ids = random_ids[train_example_nums:]

len(random_train_ids), len(random_test_ids)
# Out:
# (168845, 29797)

# %%
X_train = torch.as_tensor(fetched_data[random_train_ids, 1:])
Y_train = torch.as_tensor(fetched_data[random_train_ids, 0]).type(torch.int64)

X_test = torch.as_tensor(fetched_data[random_test_ids, 1:])
Y_test = torch.as_tensor(fetched_data[random_test_ids, 0]).type(torch.int64)

# %%
print(X_train, X_train.shape)
# Out:
# tensor([[ 0.0448,  0.0239, -0.0421,  ..., -0.2554,  0.1965,  0.3828],
#         [ 0.8391,  0.6574,  0.8860,  ..., -0.9298,  0.2361,  0.8857],
#         [ 0.9742,  0.2220, -0.0299,  ..., -0.3575,  0.3967,  0.4465],
#         ...,
#         [ 1.1547,  0.7468,  0.1050,  ..., -0.0637, -0.1396,  0.6223],
#         [ 0.3727,  1.2938, -0.2416,  ..., -0.6458, -0.4887, -0.9725],
#         [ 0.1079, -0.0356, -0.1902,  ..., -0.0928,  0.2080, -0.0559]],
#        dtype=torch.float64) torch.Size([168845, 300])

# %%
print(Y_train, Y_train.shape)
# Out:
# tensor([1, 1, 0,  ..., 0, 0, 1]) torch.Size([168845])

# %%
class Dataset(torch.utils.data.Dataset):
  'Characterizes a dataset for PyTorch'
  def __init__(self, X, Y):
    self.labels = Y
    self.posts = X

  def __len__(self):
    return len(self.posts)

  def __getitem__(self, index):
    post = self.posts[index]
    label = self.labels[index]
    return post, label

# %%
train_dataset = Dataset(X_train, Y_train)
test_dataset = Dataset(X_test, Y_test)

print(min(Y_train), max(Y_train))
print(Y_test)
# Out:
# tensor(0) tensor(1)
# tensor([0, 1, 1,  ..., 0, 0, 0])

# %%
def accuracy(outputs, labels):
    _, preds = torch.max(outputs, dim=1)
    return torch.tensor(torch.sum(preds == labels).item() / len(preds))

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')

# %%
device = get_default_device()
device
# Out:
# device(type='cuda')

# %%
class ClassificationBase(nn.Module):
    def training_step(self, batch):
        posts, labels = batch 
        out = self(posts.type(torch.FloatTensor).to(device))                  # Generate predictions
        loss = F.cross_entropy(out, labels.to(device)) # Calculate loss
        return loss
    
    def validation_step(self, batch):
        posts, labels = batch
        out = self(posts.type(torch.FloatTensor).to(device))                    # Generate predictions
        loss = F.cross_entropy(out, labels.to(device))   # Calculate loss
        acc = accuracy(out, labels.to(device))           # Calculate accuracy
        return {'val_loss': loss.detach(), 'val_acc': acc}
        
    def validation_epoch_end(self, outputs):
        batch_losses = [x['val_loss'] for x in outputs]
        epoch_loss = torch.stack(batch_losses).mean()   # Combine losses
        batch_accs = [x['val_acc'] for x in outputs]
        epoch_acc = torch.stack(batch_accs).mean()      # Combine accuracies
        return {'val_loss': epoch_loss.item(), 'val_acc': epoch_acc.item()}
    
    def epoch_end(self, epoch, result):
        print("Epoch [{}], val_loss: {:.4f}, val_acc: {:.4f}".format(epoch, result['val_loss'], result['val_acc']))

# %%
def evaluate(model, val_loader):
    outputs = [model.validation_step(batch) for batch in val_loader]
    return model.validation_epoch_end(outputs)

def fit(epochs, lr, model, train_loader, val_loader, opt_func=torch.optim.SGD):
    history = []
    optimizer = opt_func(model.parameters(), lr, momentum = 0.9)
    for epoch in range(epochs):
        # Training Phase 
        for batch in train_loader:
            loss = model.training_step(batch)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
        # Validation phase
        result = evaluate(model, val_loader)
        model.epoch_end(epoch, result)
        history.append(result)
    return history

# %%
def plot_losses(history):
    losses = [x['val_loss'] for x in history]
    plt.plot(losses, '-x')
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Loss vs. No. of epochs');

# %%
def plot_accuracies(history):
    accuracies = [x['val_acc'] for x in history]
    plt.plot(accuracies, '-x')
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Accuracy vs. No. of epochs');

# %%
class DNN(ClassificationBase):
  def __init__(self) -> None:
    super().__init__()
    self.fc1 = torch.nn.Linear(300, 256)
    self.fc2 = torch.nn.Linear(256, 128)
    self.fc3 = torch.nn.Linear(128, 128)
    self.fc4 = torch.nn.Linear(128, 2)


  def forward(self, x: torch.Tensor) -> torch.Tensor:     
    x = self.fc1(x)
    x = F.relu(x)
    x = self.fc2(x)
    x = F.relu(x)
    x = self.fc3(x)
    x = F.relu(x)
    x = self.fc4(x)
    return x

# %%
model = DNN()
model.to(device)
# Out:
# DNN(
#   (fc1): Linear(in_features=300, out_features=256, bias=True)
#   (fc2): Linear(in_features=256, out_features=128, bias=True)
#   (fc3): Linear(in_features=128, out_features=128, bias=True)
#   (fc4): Linear(in_features=128, out_features=2, bias=True)
# )

# %%
batch_size = 32

train_dataloader = torch.utils.data.DataLoader(train_dataset, batch_size, num_workers=1, shuffle = True, pin_memory=True)
test_dataloader = torch.utils.data.DataLoader(test_dataset, batch_size*4, num_workers=1, pin_memory=True)

# %%
history = [evaluate(model, test_dataloader)]
history
# Out:
# [{'val_loss': 0.6936690211296082, 'val_acc': 0.4922625422477722}]

# %%
history += fit(20, 0.0001 , model, train_dataloader, test_dataloader)
# Out:
# Epoch [0], val_loss: 0.6930, val_acc: 0.5093
# Epoch [1], val_loss: 0.6924, val_acc: 0.5162
# Epoch [2], val_loss: 0.6917, val_acc: 0.5272
# Epoch [3], val_loss: 0.6910, val_acc: 0.5299
# Epoch [4], val_loss: 0.6902, val_acc: 0.5345
# Epoch [5], val_loss: 0.6893, val_acc: 0.5359
# Epoch [6], val_loss: 0.6883, val_acc: 0.5383
# Epoch [7], val_loss: 0.6874, val_acc: 0.5405
# Epoch [8], val_loss: 0.6865, val_acc: 0.5434
# Epoch [9], val_loss: 0.6860, val_acc: 0.5421
# Epoch [10], val_loss: 0.6853, val_acc: 0.5472
# Epoch [11], val_loss: 0.6851, val_acc: 0.5459
# Epoch [12], val_loss: 0.6846, val_acc: 0.5478
# Epoch [13], val_loss: 0.6840, val_acc: 0.5513
# Epoch [14], val_loss: 0.6838, val_acc: 0.5496
# Epoch [15], val_loss: 0.6840, val_acc: 0.5482
# Epoch [16], val_loss: 0.6834, val_acc: 0.5508
# Epoch [17], val_loss: 0.6833, val_acc: 0.5499
# Epoch [18], val_loss: 0.6826, val_acc: 0.5539
# Epoch [19], val_loss: 0.6824, val_acc: 0.5536

# %%
history += fit(10, 0.00001 , model, train_dataloader, test_dataloader)
# Out:
# Epoch [0], val_loss: 0.6825, val_acc: 0.5540
# Epoch [1], val_loss: 0.6824, val_acc: 0.5547
# Epoch [2], val_loss: 0.6824, val_acc: 0.5540
# Epoch [3], val_loss: 0.6824, val_acc: 0.5540
# Epoch [4], val_loss: 0.6824, val_acc: 0.5540
# Epoch [5], val_loss: 0.6823, val_acc: 0.5543
# Epoch [6], val_loss: 0.6823, val_acc: 0.5542
# Epoch [7], val_loss: 0.6823, val_acc: 0.5542
# Epoch [8], val_loss: 0.6823, val_acc: 0.5544
# Epoch [9], val_loss: 0.6822, val_acc: 0.5544

# %%
plot_losses(history)

# %%
plot_accuracies(history)

# %%
evaluate(model, test_dataloader)
# Out:
# {'val_loss': 0.6822229623794556, 'val_acc': 0.5544069409370422}

# %%
torch.save(model.state_dict(), 'emotion_classification-feedforward.pth')
