# %% [markdown]
# https://scikit-learn.org/stable/modules/svm.html

# %%
import numpy as np
import cv2
import csv
import matplotlib.pyplot as plt
import random
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report
import pandas as pd

from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# Load preprocessed data for SVM
file_path = '/content/drive/MyDrive/NLP_Workspace/Data/SVM_Binary_Labeled/'

df_data = pd.read_csv(file_path + "J_vs_P_data.csv")[:-1]

# with open(file_path + 'post_vectorized.csv', 'r') as file:
#   csvreader = csv.reader(file)
#   example = 0
#   for row in csvreader:
#     if example == 0:
#       example += 1
#     else:
#       if example == 1:
#         print(row)
#       #fetched_data[example] = np.array([float(x) for x in row[1]].append(row[3]))
#       example+=1

# %%
# with open(file_path + 'post_labels.csv', 'r') as file:
#   csvreader1 = csv.reader(file)
#   labels = list(csvreader1)
# for i in range (0, 20):
#   index = random.randint(0, len(labels))
#   print(labels[index], index)

# %%
labels = np.hstack(df_data.to_numpy()[:,:1])
data = df_data.to_numpy()[:,1:]
print(len(labels))
print(len(data))
# Out:
# 198642
# 198642

# %%
LENGTH_DATA = len(labels)

import random
train_example_nums = int(0.85 * LENGTH_DATA)
val_example_nums = int(0.15 * LENGTH_DATA)

random_ids = [i for i in range(LENGTH_DATA)]
random.Random(4).shuffle(random_ids)

random_train_ids = random_ids[:train_example_nums]
random_validation_ids = random_ids[train_example_nums:]

print(len(random_train_ids), len(random_validation_ids))


X_train = np.array(data[random_train_ids])
Y_train = np.array(labels[random_train_ids])

X_vali = np.array(data[random_validation_ids])
Y_vali = np.array(labels[random_validation_ids])
# Out:
# 168845 29797

# %%
print(X_train)
# Out:
# [[-0.25012207 -0.05151367 -0.63293457 ... -0.17895508  0.02599335
#    0.22894287]
#  [ 0.04101562 -0.05706787 -0.2109375  ...  0.02142334  0.30273438
#    0.12304688]
#  [ 0.33834839  1.74066162 -0.39749146 ... -0.6595459   0.10388184
#    0.16711426]
#  ...
#  [ 1.15466309  0.74680328  0.10501099 ... -0.06365967 -0.1395874
#    0.62225342]
#  [ 0.77905273  0.38275146 -0.35229492 ... -0.84277344 -0.42822266
#    0.58764648]
#  [ 0.33789062  0.6574707   0.27685547 ...  0.21716309  0.21472168
#   -0.13171387]]

# %%
print(Y_train)
# Out:
# [1. 1. 0. ... 0. 0. 1.]

# %%
print(X_vali)
# Out:
# [[ 0.40429688  0.32792664  0.17718506 ... -0.24012756 -0.65948486
#   -0.19213867]
#  [ 0.26245117  0.27490234 -0.02587891 ... -0.54785156 -0.51757812
#    0.46972656]
#  [ 1.60168457  0.26605225 -0.15435791 ... -0.9329834   0.61566162
#   -0.58459473]
#  ...
#  [ 0.25732422  0.93417358  0.09555054 ...  0.66188049  1.23907471
#   -0.67724609]
#  [-0.13769531 -0.4588623   0.08178711 ... -0.13293457  0.20581055
#    1.15194702]
#  [-0.23947144  0.10864258  0.02645874 ... -0.24804688  0.07006836
#   -0.09820557]]

# %%
print(Y_vali)
# Out:
# [0. 1. 1. ... 0. 0. 0.]

# %%
svm = LinearSVC(verbose=0)
svm.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# LinearSVC()

# %%
Y_pred = svm.predict(X_vali)

# %%
report = classification_report(Y_vali, Y_pred)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.52      0.68      0.59     14804
#          1.0       0.55      0.39      0.45     14993
#
#     accuracy                           0.53     29797
#    macro avg       0.54      0.53      0.52     29797
# weighted avg       0.54      0.53      0.52     29797
