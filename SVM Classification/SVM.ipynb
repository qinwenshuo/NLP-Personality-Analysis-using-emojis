# %% [markdown]
# https://scikit-learn.org/stable/modules/svm.html

# %%
import numpy as np
import cv2
import csv
import matplotlib.pyplot as plt
import random
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load preprocessed data for SVM
file_path = '/content/drive/MyDrive/NLP_Workspace/Data/'

df_data = pd.read_csv(file_path + "post_vectorized.csv")
df_label = pd.read_csv(file_path + "post_labels.csv")


# with open(file_path + 'post_vectorized.csv', 'r') as file:
#   csvreader = csv.reader(file)
#   example = 0
#   for row in csvreader:
#     if example == 0:
#       example += 1
#     else:
#       if example == 1:
#         print(row)
#       #fetched_data[example] = np.array([float(x) for x in row[1]].append(row[3]))
#       example+=1

# %%
# with open(file_path + 'post_labels.csv', 'r') as file:
#   csvreader1 = csv.reader(file)
#   labels = list(csvreader1)
# for i in range (0, 20):
#   index = random.randint(0, len(labels))
#   print(labels[index], index)

# %%
fetched_data = df_data.to_numpy()
len(fetched_data), len(fetched_data[0])
# Out:
# (198642, 300)

# %%
Labels = df_label.to_numpy().flatten()
len(Labels), Labels[-1]
# Out:
# (198642, 15)

# %%
LENGTH_DATA = len(df_label)

import random
train_example_nums = int(0.85 * LENGTH_DATA)
val_example_nums = int(0.15 * LENGTH_DATA)

random_ids = [i for i in range(LENGTH_DATA)]
random.Random(4).shuffle(random_ids)

random_train_ids = random_ids[:train_example_nums]
random_validation_ids = random_ids[train_example_nums:]

print(len(random_train_ids), len(random_validation_ids))


X_train = np.array(fetched_data[random_train_ids])
Y_train = np.array(Labels[random_train_ids])

X_vali = np.array(fetched_data[random_validation_ids])
Y_vali = np.array(Labels[random_validation_ids])
# Out:
# 168845 29797

# %%
print(X_vali)
# Out:
# [[ 0.84301758  1.18139648  0.06298828 ... -0.97180176  0.51763916
#    0.70721436]
#  [-0.32519531 -0.01269531  0.12423706 ... -0.26220703 -0.3137207
#    0.01281738]
#  [ 1.04714966 -0.3036499  -0.1111145  ... -0.72323608  0.87554932
#   -0.02490234]
#  ...
#  [ 0.55578613  0.18707275 -0.19775391 ... -0.21203613  0.1217041
#   -0.35620117]
#  [ 0.9085083   0.63818359 -0.22039795 ... -0.69702148  0.50398254
#    0.32452393]
#  [ 0.8236084   0.92651367 -0.2086792  ...  0.0375824  -0.5904541
#    0.03479004]]

# %%
print(Y_vali)
# Out:
# [ 3 14  9 ...  2  6  4]

# %%
svm = LinearSVC(verbose=0)
svm.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/svm/_base.py:1206: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# LinearSVC()

# %%
Y_pred = svm.predict(X_vali)

# %%
report = classification_report(Y_vali, Y_pred)

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.11      0.01      0.01      1865
#            1       0.21      0.00      0.01      1775
#            2       0.12      0.01      0.02      1861
#            3       0.10      0.01      0.02      1881
#            4       0.07      0.73      0.13      1820
#            5       0.10      0.25      0.14      1944
#            6       0.23      0.11      0.15      1833
#            7       0.12      0.03      0.05      1820
#            8       0.12      0.01      0.02      1922
#            9       0.12      0.01      0.01      1860
#           10       0.08      0.04      0.05      1915
#           11       0.12      0.06      0.08      1865
#           12       0.00      0.00      0.00      1836
#           13       0.14      0.03      0.05      1863
#           14       0.11      0.07      0.08      1876
#           15       0.14      0.06      0.08      1861
#
#     accuracy                           0.09     29797
#    macro avg       0.12      0.09      0.06     29797
# weighted avg       0.12      0.09      0.06     29797
